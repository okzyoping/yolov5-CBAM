# %% [markdown]
# Hello, my name is Okzy Oping. Hopefully, with the implementation of this program, we can all enhance artificial intelligence development in the field of vision.
#
# For further information, please feel free to reach out to me here:
#
# ---Instagram: www.instagram.com/okzy_oping/
#
# ---LinkedIn: www.linkedin.com/in/okzy-oping
#
# ---Facebook: www.facebook.com/opingokzy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r -v "/content/drive/MyDrive/dataset/dataset-sefety.zip" -d /content/
# !unzip "/content/dataset-sefety.zip" -d /content/
# Out:
# '/content/drive/MyDrive/dataset/dataset-sefety.zip' -> '/content/dataset-sefety.zip'
# Archive:  /content/dataset-sefety.zip
#  extracting: /content/README.dataset.txt
#  extracting: /content/README.roboflow.txt
#  extracting: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/ppe_0000_jpg.rf.c102a9a7c8dec01565a8f95ff295974c.jpg
#  extracting: /content/test/images/ppe_0004_jpg.rf.c3265071237f64a4f0c3e1bf3048f923.jpg
#  extracting: /content/test/images/ppe_0008_jpg.rf.356284e8df05dcd239cb91cf53b51c83.jpg
#  extracting: /content/test/images/ppe_0009_jpg.rf.68866a74a26b99495ad80bc41b7a2897.jpg
#  extracting: /content/test/images/ppe_0013_jpg.rf.a88d9ccde80be57995e344d94a033f3a.jpg
#  extracting: /content/test/images/ppe_0014_jpg.rf.6c486303c2cf17986ff64702b0ce0dd7.jpg
#  extracting: /content/test/images/ppe_0038_jpg.rf.e542ed77414548742efb104c27af9902.jpg
# ...

# %%
# !cp -r -v "/content/drive/MyDrive/yolov5/yolov5-CBAM.zip" -d /content/
# !unzip "/content/yolov5-CBAM.zip" -d /content/
# Out:
# '/content/drive/MyDrive/yolov5/yolov5-CBAM.zip' -> '/content/yolov5-CBAM.zip'
# Archive:  /content/yolov5-CBAM.zip
#    creating: /content/yolov5-CBAM/
#   inflating: /content/yolov5-CBAM/LICENSE
#   inflating: /content/yolov5-CBAM/README.md
#   inflating: /content/yolov5-CBAM/detect.py
#   inflating: /content/yolov5-CBAM/export.py
#   inflating: /content/yolov5-CBAM/hubconf.py
#   inflating: /content/yolov5-CBAM/predict.py
#   inflating: /content/yolov5-CBAM/requirements.txt
#   inflating: /content/yolov5-CBAM/train.py
#   inflating: /content/yolov5-CBAM/val.py
#   inflating: /content/yolov5-CBAM/yolov5s.pt
#    creating: /content/yolov5-CBAM/__pycache__/
#   inflating: /content/yolov5-CBAM/__pycache__/val.cpython-38.pyc
#    creating: /content/yolov5-CBAM/.git/
#   inflating: /content/yolov5-CBAM/.git/description
#   inflating: /content/yolov5-CBAM/.git/index
#   inflating: /content/yolov5-CBAM/.git/config
#   inflating: /content/yolov5-CBAM/.git/packed-refs
# ...

# %%
# %cd /content/yolov5-CBAM
# Out:
# /content/yolov5-CBAM

# %%
# %pip install -qr requirements.txt # install dependencies
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.4 MB/s eta 0:00:00

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/data.yaml --cfg yolov5n-CBAM.yaml --weights yolov5n.pt --cache
# Out:
# 2024-04-25 20:58:31.841293: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-25 20:58:31.841390: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-25 20:58:31.845153: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/datasets/American-Mushrooms-1/test/images, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-471-g2993c3f torch 1.9.0+cu102 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients, 16.3 GFLOPs
# image 1/5 /content/datasets/American-Mushrooms-1/test/images/chanterelle_02_jpg.rf.a75f69cbc359b824bb7ab938aae0f78c.jpg: 416x416 4 chanterelles, Done. (0.006s)
# image 2/5 /content/datasets/American-Mushrooms-1/test/images/chanterelle_03_jpg.rf.846e06d86f791840504a794757a1d309.jpg: 416x416 2 chanterelles, Done. (0.006s)
# ...
